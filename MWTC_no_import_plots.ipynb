# %%
import numpy as np
import matplotlib.pyplot as plt
import csv, datetime, random
import matplotlib.dates as mdates

# %%
plt.figure(figsize=(10,6))
plt.title("Overview of Beanie Temperature Statistics across all subjects", fontsize=15)

# Baseline in Gym
plt.plot([0.15], [27.09], marker="o", color="#FF142C", label="Beanie Tag #1")
plt.plot([0.30], [27.36], marker="o", color="#E6B403", label="Beanie Tag #2")
plt.plot([0.45], [26.68], marker="o", color="#39A30F", label="Beanie Tag #3")
plt.plot([0.60], [29.47], marker="o", color="#0786DB", label="Beanie Tag Left")
plt.plot([0.75], [26.71], marker="o", color="#8800A3", label="Beanie Tag Right")
plt.errorbar([0.15], [27.09], yerr=[2.35], color="#FF142C", capsize=5)
plt.errorbar([0.30], [27.36], yerr=[2.81], color="#E6B403", capsize=5)
plt.errorbar([0.45], [26.68], yerr=[1.29], color="#39A30F", capsize=5)
plt.errorbar([0.60], [29.47], yerr=[1.31], color="#0786DB", capsize=5)
plt.errorbar([0.75], [26.71], yerr=[3.55], color="#8800A3", capsize=5)

# Pre-Immersion Outside
plt.plot([1.15], [21.36], marker="o", color="#FF142C")
plt.plot([1.30], [22.42], marker="o", color="#E6B403")
plt.plot([1.45], [24.13], marker="o", color="#39A30F")
plt.plot([1.60], [21.24], marker="o", color="#0786DB")
plt.plot([1.75], [24.62], marker="o", color="#8800A3")
plt.errorbar([1.15], [21.36], yerr=[2.61], color="#FF142C", capsize=5)
plt.errorbar([1.30], [22.42], yerr=[3.04], color="#E6B403", capsize=5)
plt.errorbar([1.45], [24.13], yerr=[2.97], color="#39A30F", capsize=5)
plt.errorbar([1.60], [21.24], yerr=[3.46], color="#0786DB", capsize=5)
plt.errorbar([1.75], [24.62], yerr=[2.53], color="#8800A3", capsize=5)

# Post-Immersion Outside
plt.plot([2.15], [11.22], marker="o", color="#FF142C")
plt.plot([2.30], [13.97], marker="o", color="#E6B403")
plt.plot([2.45], [13.46], marker="o", color="#39A30F")
plt.plot([2.60], [13.77], marker="o", color="#0786DB")
plt.plot([2.75], [17.56], marker="o", color="#8800A3")
plt.errorbar([2.15], [11.22], yerr=[1.37], color="#FF142C", capsize=5)
plt.errorbar([2.30], [13.97], yerr=[2.01], color="#E6B403", capsize=5)
plt.errorbar([2.45], [13.46], yerr=[2.47], color="#39A30F", capsize=5)
plt.errorbar([2.60], [13.77], yerr=[0.99], color="#0786DB", capsize=5)
plt.errorbar([2.75], [17.56], yerr=[1.26], color="#8800A3", capsize=5)

# 2nd Dry Shirt
plt.plot([3.15], [16.28], marker="o", color="#FF142C")
plt.plot([3.30], [20.40], marker="o", color="#E6B403")
plt.plot([3.45], [24.57], marker="o", color="#39A30F")
plt.plot([3.60], [20.22], marker="o", color="#0786DB")
plt.plot([3.75], [18.63], marker="o", color="#8800A3")
plt.errorbar([3.15], [16.28], yerr=[3.65], color="#FF142C", capsize=5)
plt.errorbar([3.30], [20.40], yerr=[4.93], color="#E6B403", capsize=5)
plt.errorbar([3.45], [24.57], yerr=[4.53], color="#39A30F", capsize=5)
plt.errorbar([3.60], [20.22], yerr=[3.50], color="#0786DB", capsize=5)
plt.errorbar([3.75], [18.63], yerr=[5.31], color="#8800A3", capsize=5)

plt.vlines([1,2,3], ymin=0, ymax=40, color="#C7C7C7")
plt.ylim((8, 35))
plt.xticks([],[])
plt.yticks(
    [10.0, 12.5, 15.0, 17.5, 20.0, 22.5, 25.0, 27.5, 30.0, 32.5],
    ["10.0", "12.5", "15.0", "17.5", "20.0", "22.5", "25.0", "27.5", "30.0", "32.5"],
)
plt.legend(loc="lower left")

plt.show()

# %%
plt.figure( figsize=(12.5, 6.5) )
plt.title("Arm Temperature Statistics across All Subjects", fontsize=15)

# Baseline in Gym
plt.plot([0.2], [29.20], marker="o", color="#c20024", label="Left Upper Arm")
plt.plot([0.4], [28.35], marker="o", color="#ff4f4f", label="Left Lower Arm")
plt.plot([0.6], [30.84], marker="o", color="#002c91", label="Right Upper Arm")
plt.plot([0.8], [28.26], marker="o", color="#54b2ff", label="Right Lower Arm")
plt.errorbar([0.2], [29.20], yerr=[2.06], color="#c20024", capsize=6)
plt.errorbar([0.4], [28.35], yerr=[2.91], color="#ff4f4f", capsize=6)
plt.errorbar([0.6], [30.84], yerr=[2.57], color="#002c91", capsize=6)
plt.errorbar([0.8], [28.26], yerr=[3.26], color="#54b2ff", capsize=6)

# Pre-Immersion Outside
plt.plot([1.2], [20.66], marker="o", color="#c20024")
plt.plot([1.4], [21.60], marker="o", color="#ff4f4f")
plt.plot([1.6], [19.46], marker="o", color="#002c91")
plt.plot([1.8], [22.44], marker="o", color="#54b2ff")
plt.errorbar([1.2], [20.66], yerr=[2.68], color="#c20024", capsize=6)
plt.errorbar([1.4], [21.60], yerr=[2.65], color="#ff4f4f", capsize=6)
plt.errorbar([1.6], [19.46], yerr=[2.20], color="#002c91", capsize=6)
plt.errorbar([1.8], [22.44], yerr=[4.81], color="#54b2ff", capsize=6)

# Post-Immersion Outside
plt.plot([2.2], [8.50], marker="o", color="#c20024")
plt.plot([2.4], [7.05], marker="o", color="#ff4f4f")
plt.plot([2.6], [7.91], marker="o", color="#002c91")
plt.plot([2.8], [7.77], marker="o", color="#54b2ff")
plt.errorbar([2.2], [8.50], yerr=[2.38], color="#c20024", capsize=6)
plt.errorbar([2.4], [7.05], yerr=[1.07], color="#ff4f4f", capsize=6)
plt.errorbar([2.6], [7.91], yerr=[1.44], color="#002c91", capsize=6)
plt.errorbar([2.8], [7.77], yerr=[2.15], color="#54b2ff", capsize=6)

# 2nd Dry Shirt
plt.plot([3.2], [22.15], marker="o", color="#c20024")
plt.plot([3.4], [18.08], marker="o", color="#ff4f4f")
plt.plot([3.6], [19.56], marker="o", color="#002c91")
plt.plot([3.8], [16.73], marker="o", color="#54b2ff")
plt.errorbar([3.2], [22.15], yerr=[5.53], color="#c20024", capsize=6)
plt.errorbar([3.4], [18.08], yerr=[1.97], color="#ff4f4f", capsize=6)
plt.errorbar([3.6], [19.56], yerr=[2.79], color="#002c91", capsize=6)
plt.errorbar([3.8], [16.73], yerr=[1.38], color="#54b2ff", capsize=6)

plt.vlines([1,2,3], ymin=0, ymax=40, color="#CECECE")
plt.ylim((4, 39))
plt.xticks([],[])
plt.yticks(
    [5.0, 7.5, 10.0, 12.5, 15.0, 17.5, 20.0, 22.5, 25.0, 27.5, 30.0, 32.5, 35.0, 37.5],
    ["5.0", "7.5", "10.0", "12.5", "15.0", "17.5", "20.0", "22.5", "25.0", "27.5", "30.0", "32.5", "35.0", "37.5"],
)
plt.legend(loc="lower left")

plt.show()

# %%
plt.figure( figsize=(12.5, 6.5) )
plt.title("Body (Thorax) Temperature Statistics across All Subjects", fontsize=15)

# Baseline in Gym
plt.plot([0.15], [30.56], marker="o", color="#940101", label="Back")
plt.plot([0.30], [25.01], marker="o", color="#ff4a4a", label="Back Neck")
plt.plot([0.45], [27.71], marker="o", color="#39A30F", label="Chest")
plt.plot([0.60], [27.90], marker="o", color="#072c85", label="Left Abdomen")
plt.plot([0.75], [28.56], marker="o", color="#52b5f7", label="Right Abdomen")
plt.errorbar([0.15], [30.56], yerr=[2.25], color="#940101", capsize=5)
plt.errorbar([0.30], [25.01], yerr=[5.57], color="#ff4a4a", capsize=5)
plt.errorbar([0.45], [27.71], yerr=[1.75], color="#39A30F", capsize=5)
plt.errorbar([0.60], [27.90], yerr=[2.91], color="#072c85", capsize=5)
plt.errorbar([0.75], [28.56], yerr=[4.31], color="#52b5f7", capsize=5)

# Pre-Immersion Outside
plt.plot([1.15], [21.39], marker="o", color="#940101")
plt.plot([1.30], [20.37], marker="o", color="#ff4a4a")
plt.plot([1.45], [17.03], marker="o", color="#39A30F")
plt.plot([1.60], [17.16], marker="o", color="#072c85")
plt.plot([1.75], [13.18], marker="o", color="#52b5f7")
plt.errorbar([1.15], [21.39], yerr=[3.47], color="#940101", capsize=5)
plt.errorbar([1.30], [20.37], yerr=[2.74], color="#ff4a4a", capsize=5)
plt.errorbar([1.45], [17.03], yerr=[3.14], color="#39A30F", capsize=5)
plt.errorbar([1.60], [17.16], yerr=[4.52], color="#072c85", capsize=5)
plt.errorbar([1.75], [13.18], yerr=[5.55], color="#52b5f7", capsize=5)

# Post-Immersion Outside
plt.plot([2.15], [10.28], marker="o", color="#940101")
plt.plot([2.30], [12.33], marker="o", color="#ff4a4a")
plt.plot([2.45], [6.67], marker="o", color="#39A30F")
plt.plot([2.60], [5.06], marker="o", color="#072c85")
plt.plot([2.75], [5.19], marker="o", color="#52b5f7")
plt.errorbar([2.15], [10.28], yerr=[2.94], color="#940101", capsize=5)
plt.errorbar([2.30], [12.33], yerr=[2.28], color="#ff4a4a", capsize=5)
plt.errorbar([2.45], [6.67],  yerr=[2.28], color="#39A30F", capsize=5)
plt.errorbar([2.60], [5.06],  yerr=[1.52], color="#072c85", capsize=5)
plt.errorbar([2.75], [5.19],  yerr=[1.28], color="#52b5f7", capsize=5)

# 2nd Dry Shirt
plt.plot([3.15], [17.33], marker="o", color="#940101")
plt.plot([3.30], [20.39], marker="o", color="#ff4a4a")
plt.plot([3.45], [24.06], marker="o", color="#39A30F")
plt.plot([3.60], [18.24], marker="o", color="#072c85")
plt.plot([3.75], [19.95], marker="o", color="#52b5f7")
plt.errorbar([3.15], [17.33], yerr=[3.56], color="#940101", capsize=5)
plt.errorbar([3.30], [20.39], yerr=[3.51], color="#ff4a4a", capsize=5)
plt.errorbar([3.45], [24.06], yerr=[5.42], color="#39A30F", capsize=5)
plt.errorbar([3.60], [18.24], yerr=[2.74], color="#072c85", capsize=5)
plt.errorbar([3.75], [19.95], yerr=[4.24], color="#52b5f7", capsize=5)

plt.vlines([1,2,3], ymin=0, ymax=40, color="#CFCFCF")
plt.ylim((2.5, 35))
plt.xticks([],[])
plt.yticks(
    [2.5, 5.0, 7.5, 10.0, 12.5, 15.0, 17.5, 20.0, 22.5, 25.0, 27.5, 30.0, 32.5, 35.0],
    ["2.5", "5.0", "7.5", "10.0", "12.5", "15.0", "17.5", "20.0", "22.5", "25.0", "27.5", "30.0", "32.5", "35.0"],
)
plt.legend(loc="lower left")

plt.show()
